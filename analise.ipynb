# %% [markdown]
# # 1. Introdução
#
# Olá! Bom dia a quem estiver assistindo a esse video, Meu nome é joão luiz, integrante do Grupo 30 da pos graduação IA para Devs 2025, vou estar apresentando um projeto de Machine Learning focado em prever custos médicos individuais com base em um conjunto de dados.
#
# O objetivo é explorar, visualizar e modelar os dados para entender quais fatores mais impactam o valor cobrado no seguro de saúde.
#
# Fatores como idade, gênero, IMC, número de filhos, região e se a pessoa é fumante.
#
#
#
# ```
# Edher                - RM361040
# Yago Marialva        - RM361884
# João Sá              - RM363107
# Franclin             - RM364871
# Pavão                - RM364496
# ```

# %% [markdown]
# #2. Carregamento e preparação dos dados

# %% [markdown]
# Importamos o pandas para manipulação dos dados.
#
# Carregamos o arquivo 'seguros.csv' contendo as informações sobre os segurados.
#
# Para facilitar a análise, criamos uma nova coluna chamada 'encargos_mensais', que representa os custos de forma mensal e com os dados formatados para Real para deixar a visualização mais amigável.
#
# Por fim, ordenamos os dados para visualizar os 10 maiores encargos.

# %%
# Bibliotecas, consumo de arquivo e exibição de alguns dados
import os
from scipy.stats import zscore
import pandas as pd  # Manipulação de dados

df = pd.read_csv('seguros.csv') # Carregando Arquivo

df['encargos_mensais'] = df['encargos'] / 12 # Criar nova coluna com encargos mensais

# Formatando como R$ com duas casas decimais
df['encargos_mensais_formatado'] = df['encargos_mensais'].apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))

df = df.sort_values(by='encargos_mensais', ascending=False) #Fazendo a ordenação do mais para o menor = False; Do menor para o maior = True;

# Visualizar as primeiras linhas com os novos dados#
df[['idade','gênero','imc','filhos','fumante','região', 'encargos_mensais_formatado']].head(10)
# Out:
#         idade     gênero    imc  filhos fumante   região  \
# 94747      78   feminino  31.60       5     sim  sudeste
# 94690      78   feminino  32.96       5     sim  sudeste
# 103336     79   feminino  32.58       4     sim      sul
# 120128     79   feminino  28.83       5     sim  sudeste
# 137277     79   feminino  29.06       4     sim      sul
# 103493     78  masculino  30.62       4     sim  sudeste
# 137189     79  masculino  29.05       4     sim  sudeste
# 22405      79   feminino  32.03       4     sim  sudeste
# 56604      79  masculino  29.54       5     sim      sul
# 126665     79   feminino  29.97       4     sim      sul
#
#        encargos_mensais_formatado
# 94747                 R$ 5.484,01
# 94690                 R$ 5.464,88
# 103336                R$ 5.419,53
# 120128                R$ 5.392,81
# 137277                R$ 5.386,51
# 103493                R$ 5.372,51
# 137189                R$ 5.361,61
# 22405                 R$ 5.361,03
# ...

# %% [markdown]
# # 3. Análise Inicial dos Dados

# %% [markdown]
# ## Verficando nulos (como a nossa planilha foi gerada não tem nulos)

# %%
df.isnull().sum()
# Out:
# idade                         0
# gênero                        0
# imc                           0
# filhos                        0
# fumante                       0
# região                        0
# encargos                      0
# encargos_mensais              0
# encargos_mensais_formatado    0
# dtype: int64

# %% [markdown]
# ## Descobrir o tipo de dados em cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145003 entries, 94747 to 121000
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   idade                       145003 non-null  int64
#  1   gênero                      145003 non-null  object
#  2   imc                         145003 non-null  float64
#  3   filhos                      145003 non-null  int64
#  4   fumante                     145003 non-null  object
#  5   região                      145003 non-null  object
#  6   encargos                    145003 non-null  float64
#  7   encargos_mensais            145003 non-null  float64
#  8   encargos_mensais_formatado  145003 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 11.1+ MB

# %% [markdown]
# #4. Detectando Outliers

# %% [markdown]
# Tentamos identificar alguns outliers para focar no que for mais importantes.

# %% [markdown]
# Utilizamos o describe() para analisar médias, medianas, mínimos, máximos e quartis, que nos ajudam a entender a distribuição dos encargos, idades e outros fatores.

# %%
# Resumo estatisco dos dados como:
#Quantidade total
#Media da coluna
#Desvio padrão;  Quanto maior o desvio padrão, mais espalhados estão os dados.
#Menor valor da coluna
#1° Quartil; Ou seja dados que estão abaixo de 25%;
#2° Quartil; Ou seja dados que estão abaixo de 50%;
#3° Quartil; Ou seja dados que estão abaixo de 75%;
#Maior valor da coluna
df.describe()
# Out:
#                idade            imc         filhos       encargos  \
# count  145003.000000  145003.000000  145003.000000  145003.000000
# mean       49.516741      27.993941       1.798915   44846.967039
# std        17.348343       2.002738       1.403220    6394.483346
# min        18.000000      19.190000       0.000000   28095.350000
# 25%        35.000000      26.640000       1.000000   39890.510000
# 50%        50.000000      27.990000       2.000000   44846.090000
# 75%        65.000000      29.340000       3.000000   49409.410000
# max        79.000000      36.440000       5.000000   65808.070000
#
#        encargos_mensais
# count     145003.000000
# mean        3737.247253
# std          532.873612
# min         2341.279167
# 25%         3324.209167
# 50%         3737.174167
# 75%         4117.450833
# max         5484.005833

# %% [markdown]
# ##Boxplot - Visualização gráfica
# Usamos o Boxplot que é uma boa ferramenta para detectar outliers.
#
# Considerando o encargo mensal geral dos custos médicos

# %% [markdown]
# ## Importando bibliotecas para trabalhar com graficos, matplotlib e usando

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style='whitegrid')

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df["encargos_mensais"])
plt.title("Boxplot-Custos Médicos Mensais")
plt.xlabel("Custo Mensal($)")
plt.show()

# %% [markdown]
# Concentrada entre aproximadamente `R$ 3.300` e `R$ 4.300`, com alguns valores atípicos (outliers) acima de R$ `5.300`.

# %% [markdown]
# ## Z-score (método estatístico baseado na média e desvio padrão)
# O que faz? Calcula quantos desvios padrão cada valor está distante da média.
#
# Critério: Valores com |Z| > 3 são considerados fortes candidatos a outliers.
# Cria uma nova coluna com o Z-score.
# Filtra registros cujo Z-score absoluto > 3.
#
# Resultado: 12 outliers encontrados na coluna encargos_mensais.

# %%
# Adiciona coluna com o Z-score ao dataframe
df["z-score_encargos_mensais"] = zscore(df["encargos_mensais"])

# Filtrar os outrliers com |Z| > 3
outliers_z = df[df["z-score_encargos_mensais"].abs() > 3]
print(f"(Número de outliers, features){outliers_z.shape}")

print(f"Quantidade de outliers: {len(outliers_z)}")
print(outliers_z[["encargos_mensais", "z-score_encargos_mensais"]])
# Out:
# (Número de outliers, features)(12, 10)
# Quantidade de outliers: 12
#         encargos_mensais  z-score_encargos_mensais
# 94747        5484.005833                  3.278009
# 94690        5464.885000                  3.242127
# 103336       5419.535000                  3.157022
# 120128       5392.808333                  3.106866
# 137277       5386.507500                  3.095041
# 103493       5372.512500                  3.068778
# 137189       5361.605000                  3.048309
# 22405        5361.028333                  3.047227
# 56604        5355.325833                  3.036525
# 126665       5347.549167                  3.021931
# 123168       5345.569167                  3.018216
# 105781       5342.790833                  3.013002

# %% [markdown]
# ## IQR (Intervalo Interquartil – baseado em quartis)
# Usa os quartis para identificar valores extremos, sendo mais robusto para dados assimétricos.
#
# Critério: Valores fora do intervalo Q1 - 1.5*IQR até Q3 + 1.5*IQR são outliers.
#
# Calcula Q1, Q3 e IQR.
#
# Define limites inferior e superior.
#
# Filtra os valores fora desses limites.
#
# Resultado: 21 outliers encontrados.

# %%
Q1 = df["encargos_mensais"].quantile(0.25)
Q3 = df["encargos_mensais"].quantile(0.75)
IQR = Q3 - Q1

# Definir limites
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Filtrando os outliers
outliers_iqr = df[(df["encargos_mensais"] < limite_inferior) | (df["encargos_mensais"] > limite_superior)]
print(f"(Número de outliers, features){outliers_iqr.shape}")
# Out:
# (Número de outliers, features)(21, 10)

# %% [markdown]
# # 5. Visualização dos Dados

# %% [markdown]
# ## Definindo o grafico com a quantidade encargos encontrados por mes com determinado Valor

# %%
f, ax = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(df['encargos_mensais'], kde=True, stat="percent", color='c', ax=ax)

# Definir título e eixos
plt.title('Porcentagem de cada valor encontrado em um mês', fontsize=16)
plt.xlabel('Valor do Encargo', fontsize=13)
plt.ylabel('Porcentagem (%)', fontsize=13)

# Determinar faixa de dados
min_valor = df['encargos_mensais'].min()
max_valor = df['encargos_mensais'].max()

# Arredondar para múltiplos de 200
min_tick = (min_valor // 200) * 200
max_tick = ((max_valor // 200) + 1) * 200

# Definir limites e ticks
plt.xlim(min_tick, max_tick)
plt.xticks(np.arange(min_tick, max_tick + 200, 200))

plt.show()

# %% [markdown]
# ## Gerando grafico para definir a quantidade das idades encontradas nos dados

# %%
f, ax = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(df['idade'], stat="percent", kde=True, color='c', ax=ax)

# Eixo X de 5 em 5 anos
plt.xticks(np.arange(df['idade'].min(), df['idade'].max() + 1, 5))

plt.xlabel('Idade encontrada')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição percentual da Idade Geral')
# Out:
# Text(0.5, 1.0, 'Distribuição percentual da Idade Geral')

# %% [markdown]
# ## Definindo grafico com a Quantidade de filhos geral encontrado nos dados

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 4))
ax = sns.histplot(df['filhos'], kde=True, stat="percent", color='c')

plt.xlabel('Filhos encontrados')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição Percentual de Filhos')
# Out:
# Text(0.5, 1.0, 'Distribuição Percentual de Filhos')

# %% [markdown]
# ## Definindo grafico com a Quantidade de IMC (Indice de massa corporal) encontrada nos dados

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Gerar o gráfico
f, ax = plt.subplots(1, 1, figsize=(20, 8))
sns.histplot(df['imc'], kde=True, stat="percent", color='c', ax=ax)

# Definir título e eixos
plt.xlabel('IMC encontrado')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição Percentual do IMC')

# Definir o range do eixo X entre 20 e 35
plt.xlim(20, 35)
plt.xticks(range(20, 36, 1))  # ticks de 1 em 1

plt.show()

# %% [markdown]
# ## Definindo o gráfico de fumantes vs não fumantes com porcentagens e quantidades absolutas

# %%
contagem = df['fumante'].value_counts()
porcentagem = (contagem / contagem.sum()) * 100

# Criar DataFrame com ambas as informações
dados_plot = pd.DataFrame({
    'fumante': contagem.index,
    'quantidade': contagem.values,
    'percentual': porcentagem.values
})

# Plotar
f, ax = plt.subplots(1, 1, figsize=(20, 8))
grafico = sns.barplot(data=dados_plot, x='fumante', y='percentual', color='skyblue')

# Título e eixos
plt.title('Porcentagem de Fumantes vs Não Fumantes')
plt.xlabel('Fumante?')
plt.ylabel('Porcentagem (%)')

# Adicionar rótulos com % e quantidade
for p, qtd in zip(grafico.patches, dados_plot['quantidade']):
    altura = p.get_height()
    texto = f'{altura:.1f}% ({qtd:,})'.replace(',', '.')  # Ex: 34.6% (2.300)
    grafico.annotate(texto,
                     (p.get_x() + p.get_width() / 2., altura),
                     ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.show()

# %% [markdown]
# ## Definindo grafico de cada região encontrado nos dados com porcentagens e quantidades absolutas

# %%
f, ax = plt.subplots(1, 1, figsize=(14, 8))
grafico = sns.countplot(x='região', data=df, color='skyblue')

# Título e eixos
plt.title('Quantidade de Registros por Região')
plt.xlabel('Regiões encontradas')
plt.ylabel('Quantidade')

# Total de registros para calcular a porcentagem
total = len(df)

# Adicionando os rótulos de quantidade + porcentagem na mesma linha
for p in grafico.patches:
    altura = p.get_height()
    porcentagem = 100 * altura / total
    grafico.annotate(f'{int(altura):,} ({porcentagem:.1f}%)'.replace(",", "."),
                     (p.get_x() + p.get_width() / 2., altura),
                     ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.show()

# %% [markdown]
# ## Boxplt do custo médico mensal por Gênero

# %%
sns.boxplot(x="gênero", y="encargos_mensais", data=df)
plt.title("Custo Médico por Gênero")
plt.ylabel("Custo Mensal ($)")
plt.show()

# %% [markdown]
# Analisa a relação entre idade e filhos para ver se não tem nada fora do normal, como um jovem de 18 anos ter 5 filhos

# %%
df2_idade_filhos = df[['idade', 'filhos']].groupby(df.idade)
df2_idade_filhos['filhos'].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# idade
# 18     1057.0  0.540208  0.498617  0.0  0.0  1.0  1.0  1.0
# 19     1133.0  0.541924  0.498459  0.0  0.0  1.0  1.0  1.0
# 20     1660.0  1.074096  0.811270  0.0  0.0  1.0  2.0  2.0
# 21     1684.0  1.067102  0.812637  0.0  0.0  1.0  2.0  2.0
# 22     2107.0  1.427148  1.032604  0.0  1.0  1.0  2.0  3.0
# ...       ...       ...       ...  ...  ...  ...  ...  ...
# 75     2497.0  1.835002  1.399694  0.0  1.0  2.0  3.0  5.0
# 76     2417.0  1.882913  1.424401  0.0  1.0  2.0  3.0  5.0
# 77     2354.0  1.848343  1.416444  0.0  1.0  2.0  3.0  5.0
# 78     2428.0  1.839374  1.430919  0.0  1.0  2.0  3.0  5.0
# 79     2438.0  1.863823  1.453250  0.0  1.0  2.0  3.0  5.0
#
# [62 rows x 8 columns]

# %% [markdown]
# # 6. Análises Cruzadas

# %% [markdown]
# ## Fumar e possuir idade avançada eleva os custos

# %%
df['encargos'] = df['encargos'].astype(float)
df['encargos_mensais'] = df['encargos'] / 12

# Agrupar por idade e fumante, calculando média de custo mensal
df_grouped = df.groupby(['idade', 'fumante'])['encargos_mensais'].mean().reset_index()

# Plot
plt.figure(figsize=(20, 8))
sns.lineplot(data=df_grouped, x='idade', y='encargos_mensais', hue='fumante', marker='o')

plt.title('Custos Médios Mensais por Idade e Hábito de Fumar')
plt.xlabel('Idade')
plt.ylabel('Encargo Mensal Médio (R$)')
plt.legend(title='Fumante')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conforme a região e o número de filhos os encargos aumentam

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# Criar o gráfico
f, ax = plt.subplots(1, 1, figsize=(20, 8))
grafico = sns.barplot(
    x='região',
    y='encargos_mensais',
    hue='filhos',
    data=df,
    palette='Set1',
    errorbar=None
)

ax.set_xticks(ax.get_xticks())  # Garante que está pegando as posições atuais
ax.set_xticklabels([
    '  0       1         2        3        4        5 \n Sudeste',
    '  0       1         2        3        4        5 \n Sul',
    '  0       1         2        3        4        5 \n Nordeste',
    '  0       1         2        3        4        5 \n Centro-Oeste',
    '  0       1         2        3        4        5 \n Norte'])

# Formatar o eixo Y para milhares
#formatter = ticker.FuncFormatter(lambda x, pos: f'{int(x/1000)}k')
#ax.yaxis.set_major_formatter(formatter)

# Ajustes gerais
plt.title('Encargos Médios Mensais por Região e Quantidade de Filhos')
plt.xlabel('\n Quantidade de Filhos e Região')
plt.ylabel('Encargo Mensal Médio (R$)')
#plt.xticks(rotation=45, ha='right')
plt.legend(title='Filhos')

# %% [markdown]
# Como se trata de uma base gerada percebe-se como o grafico esta perfeitamente como uma escadinha.

# %% [markdown]
# ## Esse gráfico de dispersão ajuda a perceber que fumante e idade aumentam os custos médios.

# %%
ax = sns.lmplot(x = 'idade', y = 'encargos_mensais', data=df, hue='fumante', palette='Set1', height=6, aspect= 1.5)

plt.title('Variação dos Encargos com base na Idade ou Fumante')
plt.xlabel('Idade')
plt.ylabel('Encargo (R$)')
# Out:
# Text(40.89115451388889, 0.5, 'Encargo (R$)')

# %% [markdown]
# ## Esse gráfico de dispersão ajuda a perceber que o IMC aumenta os custos médios.

# %%
# ax = sns.lmplot(x = 'imc', y = 'encargos_mensais', data=df, palette='Set2', height=6, aspect= 1.5)

sns.lmplot(
    x='imc', y='encargos_mensais',
    data=df,
    palette='Set2',
    height=6,
    aspect=1.5,
    scatter_kws={'color': 'green', 's': 12},  # cor e tamanho dos pontos
    line_kws={'color': 'red', 'linewidth': 3}   # cor e espessura da linha
)

plt.title('Variação dos Encargos com base no IMC')
plt.xlabel('IMC')
plt.ylabel('Encargo (R$)')
# Out:
# Text(20.578125, 0.5, 'Encargo (R$)')

# %% [markdown]
# ## Tabela com as definições do IMC
#
# | Faixa de IMC   | Classificação                | Interpretação                                   |
# | -------------- | ---------------------------- | ----------------------------------------------- |
# | Abaixo de 18,5 | Magreza                      | Pode indicar desnutrição ou outros problemas.   |
# | 18,5 – 24,9    | Peso normal                  | Faixa considerada saudável.                     |
# | 25 – 29,9      | Sobrepeso                    | Risco aumentado de problemas metabólicos.       |
# | 30 – 34,9      | Obesidade grau I             | Risco moderado de doenças associadas.           |
# | 35 – 39,9      | Obesidade grau II            | Risco alto de comorbidades.                     |
# | 40 ou mais     | Obesidade grau III (mórbida) | Risco muito alto; requer acompanhamento médico. |

# %% [markdown]
# # 7. Pré-Processamento dos Dados

# %% [markdown]
# ## Com o LabelEncoder para convertemos variáveis categóricas (gênero, fumante e região) em valores numéricos.

# %%
df_transformado = df.copy()

from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(df['gênero'].drop_duplicates())
df_transformado['gênero'] = label.transform(df['gênero'])
label.fit(df['fumante'].drop_duplicates())
df_transformado['fumante'] = label.transform(df['fumante'])
label.fit(df['região'].drop_duplicates())
df_transformado['região'] = label.transform(df['região'])

df_transformado.describe()
# Out:
#                idade         gênero            imc         filhos  \
# count  145003.000000  145003.000000  145003.000000  145003.000000
# mean       49.516741       0.498962      27.993941       1.798915
# std        17.348343       0.500001       2.002738       1.403220
# min        18.000000       0.000000      19.190000       0.000000
# 25%        35.000000       0.000000      26.640000       1.000000
# 50%        50.000000       0.000000      27.990000       2.000000
# 75%        65.000000       1.000000      29.340000       3.000000
# max        79.000000       1.000000      36.440000       5.000000
#
#              fumante         região       encargos  encargos_mensais  \
# count  145003.000000  145003.000000  145003.000000     145003.000000
# mean        0.199334       2.348779   44846.967039       3737.247253
# std         0.399501       1.317629    6394.483346        532.873612
# min         0.000000       0.000000   28095.350000       2341.279167
# ...

# %% [markdown]
# ## 8. Análise de Correlação entre as features e o target, quanto mais quente (Vermelho) mais influencia

# %%
df_corr = df_transformado.select_dtypes(include='number')

# Correlação com o target
cor_target = df_corr.corr()['encargos_mensais'].drop('encargos_mensais')
cor_target = cor_target.reindex(cor_target.abs().sort_values(ascending=False).index)

# Heatmap completo com colormap mais intuitivo (vermelho = alta correlação)
plt.figure(figsize=(14, 10))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Matriz de Correlação entre Variáveis Numéricas', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Agora é a hora de treinar e comparar os modelos (Modelagem Preditiva)

# %% [markdown]
# ## Importando bibliotecas necessarias

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, BayesianRidge, HuberRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_error
import numpy as np
import time

# %% [markdown]
# ## Função para calcular o MAPE (Mean Absolute Percentage Error) e os modelos logando o tempo gasto e todas as metricas para comparação

# %%
def calculate_mape(labels, predictions):
    errors = np.abs(labels - predictions)
    relative_errors = errors / np.abs(labels)
    mape = np.mean(relative_errors) * 100
    return mape

def run_model(models, x_train, x_test, y_train, y_test):
    for model in models:
        tic = time.perf_counter()
        y_test_predict = model.fit(x_train, y_train).predict(x_test)
        toc = time.perf_counter()
        mape_result = calculate_mape(y_test, y_test_predict)
        mse = mean_squared_error(y_test, y_test_predict)
        rmse = root_mean_squared_error(y_test, y_test_predict)
        r2 = r2_score(y_test, y_test_predict)
        mae = mean_absolute_error(y_test, y_test_predict)
        print(f"=== {model.__class__} ====")
        print(f"MSE: {mse:.2f}")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAPE: {mape_result:.2f}%")
        print(f"MAE: {mae:.2f}")
        print(f'r²: {r2:.2f}')
        print(f"Tempo gasto {toc - tic:0.4f} segundos")
        print('')
        # Conforme a região e o número de filhos os encargos aumentam
        f, ax = plt.subplots(1, 1, figsize=(12, 8))
        ax = sns.histplot(data=y_test_predict - y_test)

# %% [markdown]
# ## Como interpretar o MSE
# * MSE inferior: indica um melhor ajuste entre o modelo e os dados, proximo de 0
# * MSE superior: indica um ajuste pior entre o modelo e os dados
# * MSE de 0: indica um ajuste perfeito entre o modelo e os dados
# * Links:
#     - https://medium.com/@wl8380/understanding-mean-squared-error-mse-in-regression-models-9ade100c9627
#     - https://encord.com/glossary/mean-square-error-mse/
#
# ## Como interpretar o MAPE
# * Menos de 5%: Aceitavelmente preciso
# * 10% a 25%: Precisão baixa, mas aceitável
# * Maior que 25%: Precisão muito baixa
# * 0%: A previsão é a mesma que a real
# * Links:
#     - https://medium.com/@oluwatobimesh/comparing-machine-learning-models-using-mean-absolute-error-mae-mean-absolute-percentage-error-93612c284fb8
#
# ## Como interpretar o RMSE (Root Mean Squared Error)
# * RMSE inferior: Indica um melhor ajuste entre o modelo e os dados, próximo de 0.
# * RMSE superior: Indica que o modelo está cometendo grandes erros.
# * RMSE = 0: Previsões perfeitas (sem erro).
# * Mais sensível a outliers do que o MAE.
# * Links:
#
# https://medium.com/@sergio.torres.lopez/what-is-the-rmse-and-how-to-use-it-cd384f7c0ff
#
# https://en.wikipedia.org/wiki/Root-mean-square_deviation
#
# ## Como interpretar o MAE (Mean Absolute Error)
# * MAE inferior: Indica que, em média, o modelo está errando pouco.
# * MAE superior: Indica um erro médio mais alto.
# * MAE = 0: O modelo acerta exatamente todos os valores.
# * Menos sensível a outliers do que o RMSE.
# * Links:
#
# https://towardsdatascience.com/metrics-to-evaluate-your-machine-learning-algorithm-f10ba6e38234
#
# https://en.wikipedia.org/wiki/Mean_absolute_error
#
# ## Como interpretar o R² (Coeficiente de Determinação)
# * 1.0 (100%): Modelo explica toda a variabilidade dos dados.
# * 0.0 (0%): Modelo não explica nada além da média.
# * < 0.0: Modelo pior que uma simples média.
# * Mais próximo de 1, melhor é o modelo.
# * Usado para avaliar o poder explicativo do modelo.
# * Links:
#
# https://towardsdatascience.com/coefficient-of-determination-r-squared-explained-db32700d924e
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination
#
#
# # Métricas de regressão
# * Links:
#     - https://medium.com/dados-e-saude/m%C3%A9tricas-de-regress%C3%A3o-f195ed16fd8a
#     - https://blog.minitab.com/pt/analise-de-regressao-como-interpretar-o-r-quadrado-e-avaliar-a-qualidade-de-ajuste

# %% [markdown]
# ## Separando a base de dados e (treino/teste)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Limpa a coluna 'encargos' (remove R$, pontos e vírgula, e converte para float)
df['encargos'] = df['encargos'].astype(str)\
                                .str.replace('R$', '', regex=False)\
                                .str.replace('.', '', regex=False)\
                                .str.replace(',', '.', regex=False)\
                                .str.strip()\
                                .astype(float)

# Copia o dataframe original
df_transformado = df.copy()

# Aplica LabelEncoder em todas as colunas do tipo 'object'
label_encoder = LabelEncoder()
for col in df_transformado.select_dtypes(include='object').columns:
    df_transformado[col] = label_encoder.fit_transform(df_transformado[col])

# Separa os dados em X (features) e y (target)
x = df_transformado.drop(['encargos'], axis=1)
y = df_transformado['encargos']

# Divide os dados em treino e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Aplica StandardScaler (normalização dos dados)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## Configurando os modelos

# %%
lasso = Lasso(alpha=0.2, fit_intercept=True, max_iter=5000, tol=0.0001, selection='cyclic')

randomForestRegressor = RandomForestRegressor(
    n_estimators=100,
    criterion='squared_error',
    random_state=1,
    n_jobs=-1
)

models = [
    LinearRegression(),
    BayesianRidge(),
    lasso,
    HuberRegressor(max_iter=200),
    randomForestRegressor,
    DecisionTreeRegressor()
]

# Função para treinar e testar os modelos
def run_model(models, x_train, x_test, y_train, y_test):
    for model in models:
        model.fit(x_train, y_train)
        score = model.score(x_test, y_test)
        print(f'{model.__class__.__name__}: R² = {score:.4f}')

# Executa os modelos
run_model(models, x_train, x_test, y_train, y_test)
# Out:
# LinearRegression: R² = 0.1866
# BayesianRidge: R² = -0.0000
# Lasso: R² = 0.1866
# HuberRegressor: R² = 0.0981
# RandomForestRegressor: R² = 0.1229
# DecisionTreeRegressor: R² = -0.7643

# %% [markdown]
# ### Apesar de os modelos não apresentarem alta precisão, nos identificamos como um problema da base e não dos codigos feitos e decidimos por manter nesse nivel mesmo de precisão.

# %% [markdown]
# ## Treinamento e teste do modelo de Regressão Linear
#
# Cria um modelo de regressão linear (LinearRegression()).
#
# Treina o modelo com os dados de treino (x_train, y_train).
#
# Faz previsões com os dados de teste (x_test) e armazena em predictions.

# %%
model = LinearRegression()
model.fit(x_train, y_train)

predictions = model.predict(x_test)

# %% [markdown]
# ## Cálculo da média da variável alvo:

# %%
df['encargos_mensais'].mean()
# Out:
# np.float64(3737.247253240736)

# %% [markdown]
# ## Conclusão final do cálculo da média
# Considerando que a média dos encargos é de `R$ 3737,25` mensais, uma margem de erro média de `R$ 851,65` pode ser considerada aceitável. Esse resultado foi alcançado pelo modelo HuberRegressor, que apresentou o melhor desempenho entre as opções avaliadas com base nas métricas utilizadas.
