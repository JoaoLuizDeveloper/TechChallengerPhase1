# %%
import pandas as pd
df = pd.read_csv('seguros.csv')
# Criar nova coluna com encargos mensais

df['encargos_mensais'] = df['encargos'] / 12


# Formatando como R$ com duas casas decimais
df['encargos_mensais_formatado'] = df['encargos_mensais'].apply(lambda x: f"R$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))

df = df.sort_values(by='encargos_mensais', ascending=False) #Fazendo a ordenação do mais para o menor = False; Do menor para o maior = True;

# Visualizar as primeiras linhas com os novos dados#
df[['idade','gênero','imc','filhos','fumante','região', 'encargos_mensais_formatado']].head(10)

#df.head(10) # Colocar valores maiores dentro do head para exibir

#df.tail(10)  # Mostra as 10 últimas linhas
# Out:
#         idade     gênero    imc  filhos fumante   região  \
# 94747      78   feminino  31.60       5     sim  sudeste
# 94690      78   feminino  32.96       5     sim  sudeste
# 103336     79   feminino  32.58       4     sim      sul
# 120128     79   feminino  28.83       5     sim  sudeste
# 137277     79   feminino  29.06       4     sim      sul
# 103493     78  masculino  30.62       4     sim  sudeste
# 137189     79  masculino  29.05       4     sim  sudeste
# 22405      79   feminino  32.03       4     sim  sudeste
# 56604      79  masculino  29.54       5     sim      sul
# 126665     79   feminino  29.97       4     sim      sul
#
#        encargos_mensais_formatado
# 94747                 R$ 5.484,01
# 94690                 R$ 5.464,88
# 103336                R$ 5.419,53
# 120128                R$ 5.392,81
# 137277                R$ 5.386,51
# 103493                R$ 5.372,51
# 137189                R$ 5.361,61
# 22405                 R$ 5.361,03
# 56604                 R$ 5.355,33
# 126665                R$ 5.347,55

# %%
# Verficando nulos (como a nossa planilha foi gerada não tem nulos)
df.isnull().sum()
# Out:
# idade                         0
# gênero                        0
# imc                           0
# filhos                        0
# fumante                       0
# região                        0
# encargos                      0
# encargos_mensais              0
# encargos_mensais_formatado    0
# dtype: int64

# %%
# Descobrir o tipo de dados em cada coluna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145003 entries, 94747 to 121000
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   idade                       145003 non-null  int64
#  1   gênero                      145003 non-null  object
#  2   imc                         145003 non-null  float64
#  3   filhos                      145003 non-null  int64
#  4   fumante                     145003 non-null  object
#  5   região                      145003 non-null  object
#  6   encargos                    145003 non-null  float64
#  7   encargos_mensais            145003 non-null  float64
#  8   encargos_mensais_formatado  145003 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 11.1+ MB

# %%
# Resumo estatisco dos dados como:
#Quantidade total
#Media da coluna
#Desvio padrão;  Quanto maior o desvio padrão, mais espalhados estão os dados.
#Menor valor da coluna
#1° Quartil; Ou seja dados que estão abaixo de 25%; Ou seja o 1° Quartil paga até 25% do valor encontrado
#2° Quartil; Ou seja dados que estão abaixo de 50%; Ou seja o 2° Quartil paga até 50% do valor encontrado
#3° Quartil; Ou seja dados que estão abaixo de 75%; Ou seja o 3° Quartil paga até 75% do valor encontrado
#Maior valor da coluna
df.describe()
# Out:
#                idade            imc         filhos       encargos  \
# count  145003.000000  145003.000000  145003.000000  145003.000000
# mean       49.516741      27.993941       1.798915   44846.967039
# std        17.348343       2.002738       1.403220    6394.483346
# min        18.000000      19.190000       0.000000   28095.350000
# 25%        35.000000      26.640000       1.000000   39890.510000
# 50%        50.000000      27.990000       2.000000   44846.090000
# 75%        65.000000      29.340000       3.000000   49409.410000
# max        79.000000      36.440000       5.000000   65808.070000
#
#        encargos_mensais
# count     145003.000000
# mean        3737.247253
# std          532.873612
# min         2341.279167
# 25%         3324.209167
# 50%         3737.174167
# 75%         4117.450833
# max         5484.005833

# %% [markdown]
# ## Analise de distribuição dos dados através de histogramas

# %%
#Importando bibliotecas para trabalhar com graficos, matplotlib e usando tambem seaborn
#Definindo o grafico com seaborn sns
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style='whitegrid')

# %%
#Definindo o grafico com a quantidade encargos encontrados por mes com determinado Valor
#Podemos definir o Titulo, Eixo X e Y, o metodo de comparação e a exibição
f, ax = plt.subplots(1, 1, figsize=(20, 8))
ax = sns.histplot(df['encargos_mensais'], kde=True, stat="percent", color='c')

# Extrair os dados das barras do histograma
# patches = ax.patches  # retângulos do histograma

# # Obter altura (percentual) e posição central de cada barra
# bar_values = [(p.get_x() + p.get_width() / 2, p.get_height()) for p in patches]

# # Pegar as 3 maiores porcentagens
# top3 = sorted(bar_values, key=lambda x: x[1], reverse=True)[:3]

# # Anotar no gráfico
# for x, y in top3:
#   ax.text(x, -0.4, f'{x:,.2f}', ha='center', va='top', fontsize=11, fontweight='bold', color='black')

# Título e eixos
plt.title('Encargos Gerais Por mês', fontsize=16)
plt.xlabel('Valor de Encargo mensal', fontsize=13)
plt.ylabel('Porcentagem (%)', fontsize=13)
# Out:
# Text(0, 0.5, 'Porcentagem (%)')

# %%
#Gerando grafico para definir a quantidade das idades encontradas nos dados
# Criar histograma com proporção (densidade normalizada)
f, ax = plt.subplots(1, 1, figsize=(12, 8))
sns.histplot(df['idade'], stat="percent", kde=True, color='c', ax=ax)

# Eixo X de 5 em 5 anos
plt.xticks(np.arange(df['idade'].min(), df['idade'].max() + 1, 5))

plt.xlabel('Idade encontrada')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição percentual da Idade Geral')
# Out:
# Text(0.5, 1.0, 'Distribuição percentual da Idade Geral')

# %%
#Definindo grafico com a Quantidade de filhos geral encontrado nos dados
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.histplot(df['filhos'], kde=True, stat="percent", color='c')

plt.xlabel('Filhos encontrados')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição Percentual de Filhos')
# Out:
# Text(0.5, 1.0, 'Distribuição Percentual de Filhos')

# %%
#Definindo grafico com a Quantidade de IMC (Indice de massa corporal) encontrada nos dados
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.histplot(df['imc'], kde=True, stat="percent", color='c')

plt.xlabel('IMC encontrado')
plt.ylabel('Porcentagem (%)')
plt.title('Distribuição Percentual do IMC')
plt.show()

# %%
# Definindo o gráfico de fumantes vs não fumantes
# Calcular porcentagens e quantidades absolutas
contagem = df['fumante'].value_counts()
porcentagem = (contagem / contagem.sum()) * 100

# Criar DataFrame com ambas as informações
dados_plot = pd.DataFrame({
    'fumante': contagem.index,
    'quantidade': contagem.values,
    'percentual': porcentagem.values
})

# Plotar
f, ax = plt.subplots(1, 1, figsize=(12, 8))
grafico = sns.barplot(data=dados_plot, x='fumante', y='percentual', color='skyblue')

# Título e eixos
plt.title('Porcentagem de Fumantes vs Não Fumantes')
plt.xlabel('Fumante?')
plt.ylabel('Porcentagem (%)')

# Adicionar rótulos com % e quantidade
for p, qtd in zip(grafico.patches, dados_plot['quantidade']):
    altura = p.get_height()
    texto = f'{altura:.1f}% ({qtd:,})'.replace(',', '.')  # Ex: 34.6% (2.300)
    grafico.annotate(texto,
                     (p.get_x() + p.get_width() / 2., altura),
                     ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.show()

# %%
#Definindo grafico com a Quantidade de cada região encontrado nos dados
# Cria o gráfico de contagem por região
f, ax = plt.subplots(1, 1, figsize=(12, 8))
grafico = sns.countplot(x='região', data=df, color='skyblue')

# Título e eixos
plt.title('Quantidade de Registros por Região')
plt.xlabel('Regiões encontradas')
plt.ylabel('Quantidade')

# Adicionando os rótulos acima de cada barra
for p in grafico.patches:
    altura = p.get_height()
    grafico.annotate(f'{int(altura):,}'.replace(",", "."),  # Formato tipo 25.000
                     (p.get_x() + p.get_width() / 2., altura),
                     ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.show()

# %%
# Analisa a relação entre idade e filhos para ver se não tem nada fora do normal, como um jovem de 18 anos ter 5 filhos
df2_idade_filhos = df[['idade', 'filhos']].groupby(df.idade)
df2_idade_filhos['filhos'].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# idade
# 18     1057.0  0.540208  0.498617  0.0  0.0  1.0  1.0  1.0
# 19     1133.0  0.541924  0.498459  0.0  0.0  1.0  1.0  1.0
# 20     1660.0  1.074096  0.811270  0.0  0.0  1.0  2.0  2.0
# 21     1684.0  1.067102  0.812637  0.0  0.0  1.0  2.0  2.0
# 22     2107.0  1.427148  1.032604  0.0  1.0  1.0  2.0  3.0
# ...       ...       ...       ...  ...  ...  ...  ...  ...
# 75     2497.0  1.835002  1.399694  0.0  1.0  2.0  3.0  5.0
# 76     2417.0  1.882913  1.424401  0.0  1.0  2.0  3.0  5.0
# 77     2354.0  1.848343  1.416444  0.0  1.0  2.0  3.0  5.0
# 78     2428.0  1.839374  1.430919  0.0  1.0  2.0  3.0  5.0
# 79     2438.0  1.863823  1.453250  0.0  1.0  2.0  3.0  5.0
#
# [62 rows x 8 columns]

# %%
# Fumar com idade alta pode elevar custo
# Garante que os encargos estão como float e já divididos por 12
df['encargos'] = df['encargos'].astype(float)
df['encargos_mensais'] = df['encargos'] / 12

# Agrupar por idade e fumante, calculando média de custo mensal
df_grouped = df.groupby(['idade', 'fumante'])['encargos_mensais'].mean().reset_index()

# Plot
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_grouped, x='idade', y='encargos_mensais', hue='fumante', marker='o')

plt.title('Custos Médios Mensais por Idade e Hábito de Fumar')
plt.xlabel('Idade')
plt.ylabel('Encargo Mensal Médio (R$)')
plt.legend(title='Fumante')
plt.grid(True)
plt.tight_layout()
plt.show()

#conclusão pode impactar, no entanto segue subindo os custos considerando as idades

# %%
# Conforme a região e o número de filhos os encargos aumentam
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='região', y='encargos', hue='filhos', data=df, palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Conforme a região e o número de filhos os encargos aumentam
#       2 f, ax = plt.subplots(1, 1, figsize=(12, 8))
# ----> 3 ax = sns.barplot(x='região', y='encargos', hue='filhos', data=df, palette='Set1')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1280, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1273 for sub_vars, sub_data in self.iter_data(iter_vars,
#    1274                                          from_comp_data=True,
#    1275                                          allow_empty=True):
#    1277     ax = self._get_axes(sub_vars)
#    1279     agg_data = sub_data if sub_data.empty else (
# -> 1280         sub_data
#    1281         .groupby(self.orient)
#    1282         .apply(aggregator, agg_var, **groupby_apply_include_groups(False))
#    1283         .reset_index()
#    1284     )
#    1286     agg_data["width"] = width * self._native_width
#    1287     if dodge:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1819, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1816     f = func
#    1818 if not include_groups:
# -> 1819     return self._python_apply_general(f, self._obj_with_exclusions)
#    1821 # ignore SettingWithCopy here in case the user mutates
#    1822 with option_context("mode.chained_assignment", None):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)
#    1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)
#    1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1809, in GroupBy.apply.<locals>.f(g)
#    1807 @wraps(func)
#    1808 def f(g):
# -> 1809     return func(g, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_statistics.py:517, in EstimateAggregator.__call__(self, data, var)
#     515 elif self.error_method == "ci":
#     516     units = data.get("units", None)
# --> 517     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
#     518     err_min, err_max = _percentile_interval(boots, self.error_level)
#     520 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\algorithms.py:99, in bootstrap(*args, **kwargs)
#      97 for i in range(int(n_boot)):
#      98     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
# ---> 99     sample = [a.take(resampler, axis=0) for a in args]
#     100     boot_dist.append(f(*sample, **func_kwargs))
#     101 return np.array(boot_dist)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\algorithms.py:99, in <listcomp>(.0)
#      97 for i in range(int(n_boot)):
#      98     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
# ---> 99     sample = [a.take(resampler, axis=0) for a in args]
#     100     boot_dist.append(f(*sample, **func_kwargs))
#     101 return np.array(boot_dist)
#
# KeyboardInterrupt:

# %%
# Percebe que fumante, idade tem encargos maiores
ax = sns.lmplot(x = 'idade', y = 'encargos', data=df, hue='fumante', palette='Set1')
ax = sns.lmplot(x = 'imc', y = 'encargos', data=df, hue='fumante', palette='Set2')

# %% [markdown]
# ## Antes de começar vamos realizar um pré-processamento

# %%
df_transformado = df.copy()

from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(df['gênero'].drop_duplicates())
df_transformado['gênero'] = label.transform(df['gênero'])
label.fit(df['fumante'].drop_duplicates())
df_transformado['fumante'] = label.transform(df['fumante'])
label.fit(df['região'].drop_duplicates())
df_transformado['região'] = label.transform(df['região'])

df_transformado.describe()
# Out:
#                idade         gênero            imc         filhos  \
# count  145003.000000  145003.000000  145003.000000  145003.000000
# mean       49.516741       0.498962      27.993941       1.798915
# std        17.348343       0.500001       2.002738       1.403220
# min        18.000000       0.000000      19.190000       0.000000
# 25%        35.000000       0.000000      26.640000       1.000000
# 50%        50.000000       0.000000      27.990000       2.000000
# 75%        65.000000       1.000000      29.340000       3.000000
# max        79.000000       1.000000      36.440000       5.000000
#
#              fumante         região       encargos  encargos_mensais
# count  145003.000000  145003.000000  145003.000000     145003.000000
# mean        0.199334       2.348779   44846.967039       3737.247253
# std         0.399501       1.317629    6394.483346        532.873612
# min         0.000000       0.000000   28095.350000       2341.279167
# 25%         0.000000       1.000000   39890.510000       3324.209167
# 50%         0.000000       3.000000   44846.090000       3737.174167
# 75%         0.000000       3.000000   49409.410000       4117.450833
# max         1.000000       4.000000   65808.070000       5484.005833

# %% [markdown]
# ## Vamos verficiar as correlações entre as features e o target, quanto mais quente (rosa) mais influencia

# %%
#Verificando a influencia que as colunas tem em relação ao encargo final
#f, ax = plt.subplots(1, 1, figsize=(10, 10))
df_corr = df_transformado.select_dtypes(include='number')  # seleciona só colunas numéricas

#ax = sns.heatmap(df_transformado.corr(), annot=True, cmap='cool')

# Verificando a influência das variáveis numéricas
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.heatmap(df_corr.corr(), annot=True, cmap='cool')

# %% [markdown]
# # Agora é a hora de treinar e comparar os modelos

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, BayesianRidge, HuberRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_error
import numpy as np
import time

# %%
# Função para calcular o MAPE (Mean Absolute Percentage Error)
def calculate_mape(labels, predictions):
    errors = np.abs(labels - predictions)
    relative_errors = errors / np.abs(labels)
    mape = np.mean(relative_errors) * 100
    return mape

# Executa os modelos logando o tempo gasto e todas as metricas para posterior comparação
def run_model(models, x_train, x_test, y_train, y_test):
    for model in models:
        tic = time.perf_counter()
        y_test_predict = model.fit(x_train, y_train).predict(x_test)
        toc = time.perf_counter()
        mape_result = calculate_mape(y_test, y_test_predict)
        mse = mean_squared_error(y_test, y_test_predict)
        rmse = root_mean_squared_error(y_test, y_test_predict)
        r2 = r2_score(y_test, y_test_predict)
        mae = mean_absolute_error(y_test, y_test_predict)
        print(f"=== {model.__class__} ====")
        print(f"MSE: {mse:.2f}")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAPE: {mape_result:.2f}%")
        print(f"MAE: {mae:.2f}")
        print(f'r²: {r2:.2f}')
        print(f"Tempo gasto {toc - tic:0.4f} segundos")
        print('')
        # Conforme a região e o número de filhos os encargos aumentam
        f, ax = plt.subplots(1, 1, figsize=(12, 8))
        ax = sns.histplot(data=y_test_predict - y_test)

# %% [markdown]
# ## Como interpretar o MSE
# * MSE inferior: indica um melhor ajuste entre o modelo e os dados
# * MSE superior: indica um ajuste pior entre o modelo e os dados
# * MSE de 0: indica um ajuste perfeito entre o modelo e os dados
# * Links:
#     - https://medium.com/@wl8380/understanding-mean-squared-error-mse-in-regression-models-9ade100c9627
#     - https://encord.com/glossary/mean-square-error-mse/
#
# ## Como interpretar o MAPE
# * Menos de 5%: Aceitavelmente preciso
# * 10% a 25%: Precisão baixa, mas aceitável
# * Maior que 25%: Precisão muito baixa
# * 0%: A previsão é a mesma que a real
# * Links:
#     - https://medium.com/@oluwatobimesh/comparing-machine-learning-models-using-mean-absolute-error-mae-mean-absolute-percentage-error-93612c284fb8
#
# # Métricas de regressão
# * Links:
#     - https://medium.com/dados-e-saude/m%C3%A9tricas-de-regress%C3%A3o-f195ed16fd8a
#     - https://blog.minitab.com/pt/analise-de-regressao-como-interpretar-o-r-quadrado-e-avaliar-a-qualidade-de-ajuste

# %%
#Separando a base de dados e configurando os modelos
from sklearn.preprocessing import LabelEncoder
# Limpa a coluna 'encargos' (remove R$, pontos e vírgula, e converte para float)
df['encargos'] = df['encargos'].astype(str)\
                                .str.replace('R$', '', regex=False)\
                                .str.replace('.', '', regex=False)\
                                .str.replace(',', '.', regex=False)\
                                .str.strip()\
                                .astype(float)

# Aqui você pode aplicar os pré-processamentos desejados (LabelEncoder, etc)
# df = aplicar_transformacoes(df)

# Se preferir salvar como df_transformado (opcional)
df_transformado = df.copy()

# Aplica LabelEncoder em todas as colunas com tipo 'object' (texto)
label_encoder = LabelEncoder()
for col in df_transformado.select_dtypes(include='object').columns:
    df_transformado[col] = label_encoder.fit_transform(df_transformado[col])

# Separa os dados em X e Y
x = df_transformado.drop(['encargos'], axis=1)
y = df_transformado['encargos']

# Divide entre treino e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Configura os modelos
lasso = Lasso(alpha=0.2, fit_intercept=True, max_iter=1000, tol=0.0001, selection='cyclic')

randomForestRegressor = RandomForestRegressor(
    n_estimators=100,
    criterion='squared_error',
    random_state=1,
    n_jobs=-1
)

models = [
    LinearRegression(),
    BayesianRidge(),
    lasso,
    HuberRegressor(max_iter=200),
    randomForestRegressor,
    DecisionTreeRegressor()
]

# Função para treinar e testar os modelos
def run_model(models, x_train, x_test, y_train, y_test):
    for model in models:
        model.fit(x_train, y_train)
        score = model.score(x_test, y_test)
        print(f'{model.__class__.__name__}: R² = {score:.4f}')

# Executa os modelos
run_model(models, x_train, x_test, y_train, y_test)
# Out:
# LinearRegression: R² = 0.1866
# BayesianRidge: R² = 0.1868
# Lasso: R² = 0.1866
# HuberRegressor: R² = 0.0957
# RandomForestRegressor: R² = 0.1233
# DecisionTreeRegressor: R² = -0.7584

# %%
df['encargos_mensais'].mean()
# Out:
# np.float64(3737.247253240736)

# %% [markdown]
# # Considerando que a média dos encargos é de RS 3737,25 mensais, uma margem de erro média de RS 851,65 pode ser considerada aceitável. Esse resultado foi alcançado pelo modelo HuberRegressor, que apresentou o melhor desempenho entre as opções avaliadas com base nas métricas utilizadas.
